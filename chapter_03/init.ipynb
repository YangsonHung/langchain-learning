# %%
from dotenv import load_dotenv
load_dotenv()

from langchain_core.messages import HumanMessage, SystemMessage
from langchain_deepseek import ChatDeepSeek

model = ChatDeepSeek(model="deepseek-v4-pro")

messages = [
    HumanMessage(content="你是什么模型，你能做什么？")
]

model.invoke(messages)
# Out:
# AIMessage(content='你好！我是 **DeepSeek**，由深度求索公司创造的AI助手。很高兴认识你！😊\n\n**关于我能做什么：**\n\n✨ **知识问答** - 可以回答各种领域的问题，从科学技术到人文历史\n\n✨ **写作助手** - 帮你写文章、修改文案、润色文字、创作故事\n\n✨ **编程帮手** - 代码编写、调试、解释代码逻辑、学习编程\n\n✨ **数据分析** - 处理文件（支持图片、PDF、Word、Excel、PPT等），读取文字信息进行分析\n\n✨ **翻译服务** - 多语言翻译，语言润色\n\n✨ **学习伙伴** - 解答疑惑、辅导功课、知识梳理\n\n✨ **创意生成** - 头脑风暴、创意策划、方案设计\n\n**我的特色：**\n- 完全**免费**使用\n- 上下文**1M**长度，可以一次处理超长文本（相当于《三体》三部曲那么多！）\n- 支持**联网搜索**（需手动开启）\n- 支持**语音输入**（App端）\n- 可以上传多种文件格式\n\n有什么我可以帮你的吗？尽管问，我会尽力为你解答！💪', additional_kwargs={'refusal': None, 'reasoning_content': '好的，用户问“你是什么模型，你能做什么？”，这是一个非常常见且直接的自我介绍类问题。用户可能是刚接触我，想了解我的基本能力和边界。\n\n我需要给出清晰、有条理的回答。先直接说明我的身份（DeepSeek，来自深度求索公司），然后分块介绍核心能力，最后补充一些实用信息如知识截止时间、文件支持和费用情况。这样结构比较完整，能让用户快速建立认知。\n\n想到了可以从这几个方面组织回复：先问候并自报家门，然后列出知识问答、写作、文件处理、联网搜索、长文本处理等主要功能，最后说明免费和使用方式，以开放性问题结尾引导进一步对话。'}, response_metadata={'token_usage': {'completion_tokens': 390, 'prompt_tokens': 11, 'total_tokens': 401, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 140, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 11}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-pro', 'system_fingerprint': 'fp_9954b31ca7_prod0820_fp8_kvcache_20260402', 'id': '4a1ab955-a942-4841-a3ea-398eeacaaf23', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019de7d1-ca4c-76e1-a364-c5e8e4be32fc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 390, 'total_tokens': 401, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 140}})

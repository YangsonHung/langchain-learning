# %%
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_redis import RedisChatMessageHistory

load_dotenv()

history = RedisChatMessageHistory(session_id="test", redis_url="redis://localhost:6379/0")
model = ChatOpenAI(
    model="doubao-seed-2.0-pro",
    base_url="https://ark.cn-beijing.volces.com/api/coding/v3")
runnable = RunnableWithMessageHistory(model, get_session_history=lambda: history)

runnable.invoke({"text":"简单对比下你刚才说的web端框架"})
# Out:
# AIMessage(content='我们主要对比最主流的三个核心Web底层框架（Vue/React/Angular），从开发者最关心的实用维度做极简对比：\n\n| 对比维度       | Vue.js                          | React                          | Angular                        |\n|----------------|---------------------------------|--------------------------------|--------------------------------|\n| 上手难度       | 最低，语法贴近原生前端三剑客，API少，学习曲线平缓 | 中等，需要先理解JSX语法、函数式思想、Hooks逻辑 | 最高，大而全的框架设计，需要掌握TS、依赖注入、模块体系等大量概念 |\n| 核心设计特点   | 渐进式设计，双向绑定开箱即用，灵活度中等，兼顾易用性和扩展性 | 函数式编程思想，单向数据流，JSX语法，灵活度极高，所有能力都可自定义 | 原生集成路由/表单/HTTP等全套能力，强制规范，强TS绑定，工程化能力内置 |\n| 适用场景       | 中小项目、快速迭代的业务，也可支撑大型企业级项目，中小团队/创业公司首选 | 复杂大型项目、大厂标配，适合有跨端（App/小程序）需求的场景 | 超大型企业级项目，对稳定性、规范要求极高的ToB/金融类长期维护项目 |\n| 国内市场占比   | 最高，中小公司/外包项目普及率极高 | 次之，大厂技术栈首选 | 最低，仅外企、特定企业级项目使用 |\n| 技术栈要求     | 基础JS即可上手，进阶才需要TS/Vite等周边 | 通常需要搭配TS、状态管理库等周边生态使用 | 必须熟练使用TS，依赖框架原生生态 |\n\n### 选型总结\n- 新手入门优先选Vue，能快速建立开发信心；\n- 想进大厂、做复杂业务或跨端开发选React；\n- 团队做超大型长期维护的企业级项目、需要强统一规范选Angular。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1588, 'prompt_tokens': 1044, 'total_tokens': 2632, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 1167, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'doubao-seed-2.0-pro', 'system_fingerprint': None, 'id': '021777900489843d323cdad39964ab14a5fcc08ad1c3650a0d7bb', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019df320-8c2b-7ec3-aabe-97230a471b17-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1044, 'output_tokens': 1588, 'total_tokens': 2632, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1167}})
